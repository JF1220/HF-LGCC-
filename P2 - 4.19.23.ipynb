# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Missing values fuctuntion to remove NAN data

# %%
missing_values = ["n/a","na", "--"]
df = pd.read_csv('https://raw.githubusercontent.com/niteen11/DataAnalyticsAcademy/master/Python/dataset_diabetes/diabetic_data.csv')

# %%
df.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# ...

# %%
df.columns
# Out:
# Index(['encounter_id', 'patient_nbr', 'race', 'gender', 'age', 'weight',
#        'admission_type_id', 'discharge_disposition_id', 'admission_source_id',
#        'time_in_hospital', 'payer_code', 'medical_specialty',
#        'num_lab_procedures', 'num_procedures', 'num_medications',
#        'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1',
#        'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum', 'A1Cresult',
#        'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide',
#        'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
#        'tolazamide', 'examide', 'citoglipton', 'insulin',
#        'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
#        'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted'],
#       dtype='object')

# %%
#CLEANIG: REMOVING UNNECESSARY COLUMNS FOR RESEARCH

# %%
drop_cols =[ 'admission_type_id', 'discharge_disposition_id', 
'admission_source_id', 'payer_code', 'medical_specialty', 'num_lab_procedures', 
'number_outpatient','number_inpatient', 'diag_1', 'diag_2', 'diag_3', 
'number_diagnoses', 'max_glu_serum', 'A1Cresult', 'metformin', 'repaglinide', 
'nateglinide', 'chlorpropamide', 'glimepiride', 'acetohexamide', 'glipizide', 
'glyburide', 'tolbutamide', 'pioglitazone', 'rosiglitazone', 'acarbose', 
'miglitol', 'troglitazone','tolazamide', 'examide', 'citoglipton', 'insulin',
 'glyburide-metformin', 'glipizide-metformin', 'glimepiride-pioglitazone',
'metformin-rosiglitazone', 'metformin-pioglitazone', 'change', 'diabetesMed']

# %%
df.drop(drop_cols, inplace = True, axis=1)

# %%
df.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    time_in_hospital  num_procedures  num_medications  number_emergency  \
# 0                 1               0                1                 0
# 1                 3               0               18                 0
# 2                 2               5               13                 0
# 3                 2               1               16                 0
# 4                 1               0                8                 0
#
#   readmitted
# 0         NO
# 1        >30
# 2         NO
# 3         NO
# 4         NO

# %%
df1= df[df['gender'] == 'Female']

# %%
#Created a new dataframe df1 and filtered to only return female as gender

# %%
df1
# Out:
#         encounter_id  patient_nbr             race  gender       age weight  \
# 0            2278392      8222157        Caucasian  Female    [0-10)      ?
# 1             149190     55629189        Caucasian  Female   [10-20)      ?
# 2              64410     86047875  AfricanAmerican  Female   [20-30)      ?
# 8              12522     48330783        Caucasian  Female   [80-90)      ?
# 9              15738     63555939        Caucasian  Female  [90-100)      ?
# ...              ...          ...              ...     ...       ...    ...
# 101757     443842136    181593374        Caucasian  Female   [70-80)      ?
# 101758     443842340    120975314        Caucasian  Female   [80-90)      ?
# 101760     443847176     50375628  AfricanAmerican  Female   [60-70)      ?
# 101762     443847782     74694222  AfricanAmerican  Female   [80-90)      ?
# 101764     443857166     31693671        Caucasian  Female   [80-90)      ?
#
# ...

# %%
#Created a new dataframe df2 from df1 and filtered to only return AfricanAmerican for race

# %%
df2=df1[df['race'] == 'AfricanAmerican']
# Out:
# <ipython-input-14-289d32913e0e>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2=df1[df['race'] == 'AfricanAmerican']

# %%
df2
# Out:
#         encounter_id  patient_nbr             race  gender       age weight  \
# 2              64410     86047875  AfricanAmerican  Female   [20-30)      ?
# 10             28236     89869032  AfricanAmerican  Female   [40-50)      ?
# 14             62256     49726791  AfricanAmerican  Female   [60-70)      ?
# 22            182796     63000108  AfricanAmerican  Female   [70-80)      ?
# 24            216156     62718876  AfricanAmerican  Female   [70-80)      ?
# ...              ...          ...              ...     ...       ...    ...
# 101696     443149208     91200537  AfricanAmerican  Female  [90-100)      ?
# 101711     443207462    100677726  AfricanAmerican  Female   [80-90)      ?
# 101730     443721236     38726739  AfricanAmerican  Female   [70-80)      ?
# 101760     443847176     50375628  AfricanAmerican  Female   [60-70)      ?
# 101762     443847782     74694222  AfricanAmerican  Female   [80-90)      ?
#
# ...

# %%
#groupby age to show how many patients were admitted that were AfricanAmerican females

# %%
df2.groupby(['age']).count()
# Out:
#           encounter_id  patient_nbr  race  gender  weight  time_in_hospital  \
# age
# [0-10)               8            8     8       8       8                 8
# [10-20)            130          130   130     130     130               130
# [20-30)            376          376   376     376     376               376
# [30-40)            750          750   750     750     750               750
# [40-50)           1547         1547  1547    1547    1547              1547
# [50-60)           2457         2457  2457    2457    2457              2457
# [60-70)           2429         2429  2429    2429    2429              2429
# [70-80)           2450         2450  2450    2450    2450              2450
# [80-90)           1307         1307  1307    1307    1307              1307
# [90-100)           274          274   274     274     274               274
#
#           num_procedures  num_medications  number_emergency  readmitted
# age
# ...

# %%
#showing overall comparison of the amount of procedures performed by gender

# %%
df.groupby(['gender'])['num_procedures'].count()
# Out:
# gender
# Female             54708
# Male               47055
# Unknown/Invalid        3
# Name: num_procedures, dtype: int64

# %%
#showing comparison of the amount of procedures performed by race

# %%
df.groupby(['race'])['num_procedures'].count()
# Out:
# race
# ?                   2273
# AfricanAmerican    19210
# Asian                641
# Caucasian          76099
# Hispanic            2037
# Other               1506
# Name: num_procedures, dtype: int64

# %%
sns.stripplot(x='age', y='num_procedures', data=df2)
# Out:
# <AxesSubplot:xlabel='age', ylabel='num_procedures'>

# %%
sns.stripplot(x='race', y='age', data=df1)
# Out:
# <AxesSubplot:xlabel='race', ylabel='age'>

# %%
#Barplot showing the amount of procedures performed by age for females

# %%
sns.barplot(x='age', y='num_procedures', data=df1)
# Out:
# <AxesSubplot:xlabel='age', ylabel='num_procedures'>

# %%
#Barplot showing the amount of procedures performed by age for AfricanAmerican females

# %%
sns.barplot(x='age', y='num_procedures', data=df2)
# Out:
# <AxesSubplot:xlabel='age', ylabel='num_procedures'>

# %%
#concluded that females had a higher admin rate compared to males, out of the females Caucasians had the highet count for diabeties. Reviewing only AfricanAmerican women ages 60-70 had the most procedures
